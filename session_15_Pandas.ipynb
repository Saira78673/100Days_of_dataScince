# %% [markdown]
# #**Pandas**

# %%
import pandas as pd
a = ['india','pakistan', 'napal','bangladas']

# %%
pd.Series(a)
# Out:
# 0        india
# 1     pakistan
# 2        napal
# 3    bangladas
# dtype: object

# %%
runs = [12,13,15,16]
pd.Series(runs)
# Out:
# 0    12
# 1    13
# 2    15
# 3    16
# dtype: int64

# %% [markdown]
# #custom tag

# %%
marks =[67,57,98,40]
sub = ['math','urdu','english','islam']
pd.Series(marks,index=sub,name = "saira k marks")
# Out:
# math       67
# urdu       57
# english    98
# islam      40
# Name: saira k marks, dtype: int64

# %% [markdown]
# #Series Attribues

# %%
# size -> tell size of items in seriers
s = pd.Series([10, 20, 30, 40], name="Marks")
s.size
# Out:
# 4

# %%
# dtype
s.dtype
# Out:
# dtype('int64')

# %%
# Name
s.name
# Out:
# 'Marks'

# %%
# Check unique values
s.is_unique
# Out:
# True

# %%
# index
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# give values
s.values
# Out:
# array([10, 20, 30, 40])

# %%
# give unique values
s.ndim
# Out:
# 1

# %%
# give shape
s.shape
# Out:
# (4,)

# %%
# Check empty
s.empty
# Out:
# False

# %%
# CHECK missing valuse
s.hasnans
# Out:
# False

# %% [markdown]
# #**Series using read_csv**

# %%
# with on col
pd.read_csv('/content/google.csv').squeeze()
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close    Volume
# 0       49.982655  44871361
# 1       53.952770  22942874
# 2       54.495735  18342897
# ...

# %%
High.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2439/3085417815.py in <cell line: 0>()
# ----> 1 High.head()
#
# NameError: name 'High' is not defined

# %%
pd.read_csv('/content/deliveries.csv')
# Out:
#     order_date delivery_date
# 0      5/24/98        2/5/99
# 1      4/22/92        3/6/98
# 2      2/10/91       8/26/92
# 3      7/21/92      11/20/97
# 4       9/2/93       6/10/98
# ..         ...           ...
# 496    6/24/91        2/2/96
# 497     9/9/91       3/30/98
# 498   11/16/90       4/27/98
# 499     6/3/93       6/13/93
# 500     1/4/90       10/3/91
#
# [501 rows x 2 columns]

# %%
from numpy import squeeze
pd.read_csv('/content/login.csv' )
# Out:
#          1   466  2017-01-07 18:24:07      Unnamed: 3
# 0        2   466  2017-01-07 18:24:55             NaN
# 1        3   458  2017-01-07 18:25:18             NaN
# 2        4   458  2017-01-07 18:26:21             NaN
# 3        5   592  2017-01-07 19:09:59             NaN
# 4        6   393  2017-01-08 00:41:19             NaN
# ...    ...   ...                  ...             ...
# 2997  2999  1307  2018-01-04 10:48:28  183.82.121.201
# 2998  3000  1230  2018-01-04 11:22:00  47.247.147.114
# 2999  3001  1307  2018-01-04 13:13:44  183.82.121.201
# 3000  3002  1307  2018-01-04 13:13:45  183.82.121.201
# 3001  3003  1224  2018-01-04 14:10:04    182.75.77.58
#
# [3002 rows x 4 columns]

# %%
pd.read_csv('/content/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs = subs = pd.read_csv('/content/subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze()
movies
movies.sample()
# Out:
# movie
# Mard Ko Dard Nahi Hota    Abhimanyu Dasani
# Name: lead, dtype: object

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort values -> mathod changing
# sort oringal data ko change nhi krta

movies.sort_values(ascending=False ).head(1).values[0]
# Out:
# 'Zulfi Sayed'

# %%
# agr sort wali original values ma changes krni ha to hum ->inplace use kry gy
copys = movies.copy()
copys.sort_values(inplace=True)

copys
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index( ascending =False ,inplace=True)

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# sum ->product
subs.sum()
subs.product()
# Out:
# np.int64(0)

# %%
# mean -> mode->media->std->var
print(subs.mean())
print(subs.mode())
print(subs.median())
print(subs.std())
print(subs.var())
# Out:
# 135.64383561643837
# 0    105
# Name: Subscribers gained, dtype: int64
# 123.0
# 62.67502303725269
# 3928.1585127201556

# %%
# min/max

subs.min()
subs.max()
# Out:
# 396

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
movies.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %% [markdown]
# #Series Indexing

# %%
# interger indexing
x = pd.Series([ 12,13,14,15,16,17,18,10])
x[0]
# Out:
# np.int64(12)

# %%
# series not work for nagative indexing

x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1590/1103187032.py in <cell line: 0>()
# ----> 1 x[-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# #Slicing

# %%
x[1:5]
# Out:
# 1    13
# 2    14
# 3    15
# 4    16
# dtype: int64

# %%
x[-5:]
# Out:
# 3    15
# 4    16
# 5    17
# 6    18
# 7    10
# dtype: int64

# %%
# Fancy Indexing
x[[2,6,5,7]]
# Out:
# 2    14
# 6    18
# 5    17
# 7    10
# dtype: int64

# %%
# last five index
movies[-5:]
# Out:
# movie
# 2 States (2014 film)          Arjun Kapoor
# 1971 (2007 film)            Manoj Bajpayee
# 1920: The Evil Returns         Vicky Ahuja
# 1920: London                 Sharman Joshi
# 1920 (film)               Rajniesh Duggall
# Name: lead, dtype: object

# %% [markdown]
# #**Editing series**

# %%
# usign indexing
pd.Series(marks,index=sub,name = "saira k marks")
# Out:
# math       67
# urdu       57
# english    98
# islam      40
# Name: saira k marks, dtype: int64

# %%
marks[-1]
# Out:
# 40

# %%
# modify the series

marks[-1]=100
marks
# Out:
# [67, 57, 98, 100]

# %%
# slicing
runs
# Out:
# [12, 13, 15, 16]

# %%
runs[2:3] = [20,40]
runs
# Out:
# [12, 13, 20, 40, 40, 16]

# %% [markdown]
# #**series with python functionality**

# %%
# len/type/dir/sorted/max/min
print(len(runs))
type(runs)
dir(subs)
# Out:
# 6
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
sorted(subs)
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %%
# type conversion
runs = pd.Series(runs)
runs.to_dict()
# Out:
# {0: 12, 1: 13, 2: 20, 3: 40, 4: 40, 5: 16}

# %% [markdown]
# # **membership operator**

# %%
# member ship works on indexes not values

'2 States (2014 film)'in movies
# Out:
#   File "/tmp/ipykernel_1590/3661528018.py", line 1
#     member ship works on indexes not values
#            ^
# SyntaxError: invalid syntax

# %%
'Alia bhatt' in movies.values
# Out:
# False

# %%
# Looping -> works on values not in index

for i in movies:
  print(i)
# Out:
# Meghan Jadhav
# Darsheel Safary
# Mithun Chakraborty
# Hrithik Roshan
# Veena Malik
# Sushmita Sen
# Sanjay Dutt
# Vivek Oberoi
# Mannara Chopra
# Shah Rukh Khan
# Emraan Hashmi
# Vinod Acharya
# Ajay Devgn
# Ajay Devgn
# Jeetendra
# Salman Khan
# Ajay Devgn
# Paresh Rawal
# Jackky Bhagnani
# Vardhan Puri
# Anupam Kher
# Shah Rukh Khan
# Anya Anand
# Ranbir Kapoor
# Gavie Chahal
# Anshuman Jha
# Deepshika Nagpal
# Tusshar Kapoor
# Rekha
# Dharmendra
# Nafisa Ali
# Arjun Rampal
# Prisha Aneja
# Siddhanth Kapoor
# Indrapal Ahuja
# Sharman Joshi
# Sikander Kher
# Kangana Ranaut
# Emraan Hashmi
# Harman Baweja
# Manu Rishi Chadha
# Boman Irani
# Shreyas Talpade
# Anil Kapoor
# Arshad Warsi
# Akshay Kumar
# Diganth
# Nana Patekar
# Gurdas Maan
# Sharman Joshi
# Amitabh Bachchan
# Salman Khan
# Ranbir Kapoor
# Elisha Kriis
# Sharman Joshi
# Naseeruddin Shah
# Arshad Warsi
# Shreyas Talpade
# Rajesh Khanna
# Niharica Raizada
# Leeza Mangaldas
# Kay Kay Menon
# Shahid Kapoor
# Kamal Haasan
# ...

# %%
#operators
# 100 + marks
marks
marks + 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1590/2801797737.py in <cell line: 0>()
#       2 # 100 + marks
#       3 marks
# ----> 4 marks + 100
#
# TypeError: can only concatenate list (not "int") to list

# %%
print(marks +5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1590/1742861633.py in <cell line: 0>()
# ----> 1 print(marks +5)
#
# TypeError: can only concatenate list (not "int") to list

# %%
# addtions

marks = pd.Series(marks)
print(marks+5)
print(marks-30)
print(marks*40)
# Out:
# 0     72
# 1     62
# 2    103
# 3    105
# dtype: int64
# 0    37
# 1    27
# 2    68
# 3    70
# dtype: int64
# 0    2680
# 1    2280
# 2    3920
# 3    4000
# dtype: int64

# %%
marks>101
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
marks <50
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# #**Boolean Indexing**

# %%
# jo jo ture ho ga wo bachy ga baki sab remove ho jaya ga false wala

runs[runs>=40].size
# Out:
# 2

# %%
# find numbes of ducks
movies[movies==40].size
# Out:
# 0

# %%
subs[subs == 0].size
# Out:
# 0

# %%
# count number of day when I had more then 200 subs a day
subs[subs>200].size
# Out:
# 59

# %%
# find actor who have done more then 20 movies
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
num_movies = movies.value_counts()
num_movies[num_movies> 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # **Ploting graph on series**

# %%
import matplotlib.pyplot as plt
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.value_counts().head(20).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
